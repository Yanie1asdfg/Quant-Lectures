# %%
策略描述：
选股：
中证500
1.开盘前计算中证500成分股，去除ST,*ST,退市,停牌,涨停   
2.计算每只股票的周线MACD，10日，20日均线    
3.如果周线刚MACD>0,同时10日均线和20日均线粘合小于1%(连续3日均线之差减少或者有交叉，在后方)

买入：满足上述条件，14：40  
最大持仓：50只
每日买入符合条件的股票
卖出：
    没有涨过5%，前5日最低点止损，
    涨过5%，开仓价止损
    10%，开仓价*1.05止盈
    15%，开仓价*1.1止盈
    20%，开仓价*1.15止盈
    ......

# %%
先做单只股票的分析
比亚迪

# %% [markdown]
# ![image.png](attachment:1483dee1-abed-4849-a58b-0991ef5db5ef.png)

# %% [markdown]
# 中证500 最大持仓50只

# %% [markdown]
# ![image.png](attachment:7e40a469-90cf-4440-b94e-8960c156e430.png)
