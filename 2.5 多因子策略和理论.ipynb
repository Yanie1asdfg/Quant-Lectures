# %% [markdown]
# # 多因子选股策略

# %% [markdown]
# 基本思想：

# %% [markdown]
# > 找到某些影响股票收益的因子，然后利用这些因子进行选股

# %% [markdown]
# 特征：因子
# 目标值：股票收益
# 多因子就是数据指标

# %% [markdown]
# ### 多因子的种类

# %% [markdown]
# ![多因子.png](attachment:cc64697b-4a82-4b2e-854a-51958f27d6f0.png)

# %% [markdown]
# 上百种因子

# %% [markdown]
# ### 如何去寻找有价值的因子？
