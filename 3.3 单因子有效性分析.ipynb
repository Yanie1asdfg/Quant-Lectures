# %% [markdown]
# # 单因子有效性分析和多因子相关性合成

# %% [markdown]
# ## 1.因子筛选

# %% [markdown]
# 因子跟收益率之间的联系 因子特征值 收益率当做目标值

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.单因子有效性分析

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 重点：某一时期的IC指的是**该期因子的暴露值**和**下期的实际回报**在横截面上的相关系数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![download.png](attachment:8b52cd42-e39c-4cab-a857-8da7ae05715b.png)![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 代码：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# p-value为统计学意义的衡量显著性的值，判定标准一般为0.05，上面的计算结果为0.52，0.52>0.05,即相关性系数有统计学意义。
