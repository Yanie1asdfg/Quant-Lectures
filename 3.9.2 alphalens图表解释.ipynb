# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# alpha:因子和超额收益alpha的相关性
# beta:因子和市场收益的相关性
# Mean Period Wise Return Top Quantile: 最高分位因子平均周期回报率
# Mean Period Wise Return Bottom Quantile: 最低分位因子平均周期回报率
# Mean Period Wise Spread: 分位收益差，越大说明区分性越好
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 可以从2个方面解读,
# 1,分位关系,分位收益从1-5,某分位较高,说明因子在这个分位的收益较高，某分位较低,说明因子在这个分位的收益较低
# 2,每个分位从左到右，持仓时间越长收益越低

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 小提琴图
# 与上图类似
# 越粗越短越好，分布更集中
# 由图中可知，分位数为3、4的因子更好

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 因子加权的多空收益,也就是所谓按照权值组合得到收益,由于负相关所以朝下的,实际情况只考虑斜率和波动情况(斜率基础上的波动),大斜率小波动

# %% [markdown]
# 展示的是**将所有因子按照因子权重进行加权后的收益**。可以看到因子在 19 年 6月 和 19 年 11月 都经历了一段较大的回撤。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 因子分组累计收益净值曲线

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 第一组平均收益分布情况
# 其中“一个月移动平均”是针对日度回测而言的，因此如果用月度回测，表示的是过去 20 个月的移动平均。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# IC 时间序列图

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# IC 的分布图，把ic值的分布直方图绘制出来，然后可以看到ic值的分布，我们希望是ic值均值越高越好，方差越小越好。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# IC 的 QQ 图，有了分布，我们要看一下是否正态分布，或者是否和某个分布很吻合。所以，我们还可以绘制qq plot，用于查看我们的ic值是否是一个正态分布，或者多大程度与正态分布相似。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# IC 热力图
