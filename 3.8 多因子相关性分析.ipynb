# %% [markdown]
# # **多因子相关性分析**

# %% [markdown]
# ![image.png](attachment:f2ff3134-ba32-45b5-94d8-ea09d7f625e4.png)

# %% [markdown]
# 建立相关性表格，筛选出相关性较强的因子

# %% [markdown]
# ![image.png](attachment:b9d31e3d-6d2e-4a23-84ed-baad0d8cf4e3.png)

# %% [markdown]
# ![image.png](attachment:aea6eff0-9f50-48ee-9df5-3536d1338c3a.png)

# %% [markdown]
# ![image.png](attachment:535c49b7-01c1-487d-864b-605f5ca14bf4.png)

# %% [markdown]
# ![image.png](attachment:9f7ae0bf-b2e9-4651-b19d-1ae79458c431.png)

# %% [markdown]
# ![image.png](attachment:ca201340-0b00-451e-bc0a-db62e1207c71.png)

# %% [markdown]
# ![image.png](attachment:13bba8bb-8ce5-4fec-ae35-b2fe21cda2fa.png)
