# %% [markdown]
# 线性回归

# %% [markdown]
# 多元线性回归

# %% [markdown]
# > 在线性回归分析中，如果有两个或两个以上的自变量，就称为多元线性回归。

# %% [markdown]
# 事实上，一种现象常常是与多个因素相联系的，由多个自变量的最优组合共同来预测或估计因变量，比只用一个自变量进行预测或估计更有效，更符合实际。因此多元线性回归比一元线性回归的实用意义更大，尤其在选股模型中，股价的涨跌的影响因素一般来说不止一个。

# %% [markdown]
# 从数学的角度来说，我们假设因变量是自变量X1,X2,X3..Xk的线性函数，用方程来表示就是：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 其中Yi表示因变量（被解释变量）的第i个观测值，而Xki则是第k个自变量（解释变量）的第i个观测值，是自变量Xk的系数，Ei是第i组观测值的残差项。在金融领域，beta0有时候会写成α，用方程来表示就是：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 多元线性回归通常采用普通最小二乘法（OLS）进行估计，普通最小二乘估计法的思路是改变

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 使得残差的平方和最小。其参数估计结果为：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 其中

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 思想：一件事情可能被好几个因素所影响
