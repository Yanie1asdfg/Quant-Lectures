# %% [markdown]
# #多因子策略流程

# %% [markdown]
# ## 1.因子挖掘

# %% [markdown]
# 1.1 因子数据的处理
# > * 去极值
# > * 标准化
# > * 中性化

# %% [markdown]
# 1.2 单因子有效性检验
# > * 因子IC分析
# > * 因子收益率分析
# > * 因子方向

# %% [markdown]
# 1.3 多因子相关性和组合分析
# > * 因子相关性
# > * 因子合成

# %% [markdown]
# ## 2.回测

# %% [markdown]
# * 多因子选股权重
#     * 打分法
#     * 回归法
# * 调仓周期
