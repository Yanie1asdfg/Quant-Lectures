# %% [markdown]
# ![image.png](attachment:531a4cef-6d97-4703-ba7b-b679e4a657a6.png)

# %% [markdown]
# 多因子打分法选股：
# * 确定因子方向，可以通过因子收益率在不同股票分位数的位置来确定
# * 因子升序：因子越小越好，若从小到大分组，1，2，3，4，5，选择前面的一组
# * 因子降序：因子越大越好，若从大到小分组，1，2，3，4，5，选择前面的一组

# %% [markdown]
# ### 打分法选股流程

# %% [markdown]
# ![image.png](attachment:1361b681-3e78-4c6e-a86e-dd0d43900867.png)

# %% [markdown]
# ![image.png](attachment:e501ddc8-4642-4474-82ff-600e69024ce0.png)

# %% [markdown]
# > 每个股票都有若干个因子的打分分数，求和，若前面的打分分数越好，选择总分数越小的前10，20只股票

# %% [markdown]
# ![image.png](attachment:e7178758-40ee-4db1-9c3e-f93e2701b35e.png)

# %% [markdown]
# ![image.png](attachment:6092dcf4-14b1-4f33-9629-ad95bbeeafe2.png)

# %% [markdown]
# ![image.png](attachment:9fc5cc03-14e9-45ae-9493-267a5093f9ef.png)

# %% [markdown]
# ![image.png](attachment:c954a96b-cf02-4fc0-b65e-f92b57e20922.png)

# %% [markdown]
# ![image.png](attachment:b1ed9179-fe28-4ed4-8671-a43e395be917.png)

# %% [markdown]
# ![image.png](attachment:bc94691f-288d-4d80-accb-3b112ffd3de2.png)
