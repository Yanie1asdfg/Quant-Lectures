# %% [markdown]
# K线序列

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 时间序列分析方向的量化分析

# %% [markdown]
# 例子：

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# 打涨停板为例

# %% [markdown]
# 每日开盘后，计算全A股中达到涨停的股票，如果这些股票有回落，然后再次达到涨停，
# 在第二次涨停前买入总资金的1/20,每日最多买入20支股票，第二天开盘时完全平仓
