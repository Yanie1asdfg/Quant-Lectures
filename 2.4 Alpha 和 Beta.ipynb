# %% [markdown]
# # 量化策略

# %% [markdown]
# > 股票量化策略，其目的都是为了获得一定的超额收益

# %% [markdown]
# ### Alpha 和 Beta

# %% [markdown]
# 每个投资策略的收益率都可以分为两部分：
# 市场回报*Beta + 超额回报 = 总回报

# %% [markdown]
# > 一部分与市场完全相关，整个市场的平均收益率乘一个Beta系数。Beta系数可以称为这个投资组合的系统风险
#
# > 另一部分和市场无关的收益叫Alpha 收益

# %% [markdown]
# 主动性的策略就是为了获取alpha收益
