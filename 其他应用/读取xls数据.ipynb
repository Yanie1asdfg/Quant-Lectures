# %%
import pandas as pd
data_xls = pd.read_excel("backtest1.xls")
df = pd.DataFrame(data_xls)
df
# Out:
#    投资组合       总收益      年化收益      一季收益      夏普比率     最大回撤率  外推收益  外推回撤  \
# 0   本策略  1.389151  0.183170 -0.002516  0.897411  0.150456   NaN   NaN
# 1  上证50  0.169013  0.030617  0.161291 -0.041382  0.340079   NaN   NaN
#
#        信息比率
# 0  0.630922
# 1       NaN

# %%
sheet=pd.read_excel("backtest1.xls",sheet_name=None)
print(list(sheet.keys()))
# Out:
# ['收益统计', '交易统计', '收益曲线', '年度收益统计', '月度收益统计', '年度最大回撤统计', '月度最大回撤统计', '每日持仓', '持仓详单', '交易记录']

# %%
sheet=pd.read_excel("backtest1.xls",sheet_name='收益曲线')
sheet
# Out:
#             日期  上证50累计收益率   策略累计收益率  上证50每日收益率  策略每日收益率
# 0     20150701  -0.046403  0.000000  -0.046403      0.0
# 1     20150702  -0.054278  0.000000  -0.008258      0.0
# 2     20150703  -0.100264  0.000000  -0.048625      0.0
# 3     20150706  -0.041821  0.000000   0.064955      0.0
# 4     20150707  -0.020062  0.000000   0.022708      0.0
# ...        ...        ...       ...        ...      ...
# 1257  20200826   0.142112  1.389151  -0.009952      0.0
# 1258  20200827   0.146605  1.389151   0.003934      0.0
# 1259  20200828   0.173662  1.389151   0.023597      0.0
# 1260  20200831   0.165108  1.389151  -0.007288      0.0
# 1261  20200901   0.169013  1.389151   0.003352      0.0
#
# [1262 rows x 5 columns]
