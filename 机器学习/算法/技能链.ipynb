# %% [markdown]
# ### 技能链

# %% [markdown]
# ![image.png](attachment:bd0540f7-2675-4001-91b0-eb449e3347d3.png)
# ![image.png](attachment:48e80033-c9dc-467d-b475-48207949f497.png)
# ![image.png](attachment:6b75b3c3-d8d3-47ab-a9da-c608845bad23.png)

# %% [markdown]
# ### 线性回归

# %% [markdown]
# 线性：两个变量之间的关系是一次函数关系的——图象是直线，叫做线性。
# 非线性：两个变量之间的关系不是一次函数关系的——图象不是直线，叫做非线性。
# 回归：人们在测量事物的时候因为客观条件所限，求得的都是测量值，而不是事物真实的值，为了能够得到真实值，无限次的进行测量，最后通过这些测量数据计算回归到真实值，这就是回归的由来。
