# %% [markdown]
# ### **1.review**

# %% [markdown]
# $\theta^{*}=\arg \min \limits_{\theta}L(\theta)$
# > L : Loss function
# > $\theta$ : parameters

# %% [markdown]
# ![image.png](attachment:bbc64e38-05db-476b-babd-c8930e5869ef.png)

# %% [markdown]
# ### **2.小心调整learning rate**

# %% [markdown]
# ![image.png](attachment:06423009-b6f2-48b6-a853-4b938ba115a2.png)

# %% [markdown]
# * 在开始的时候，可以使用较大一点的learning rate
# * 一些epochs,与destination很接近了，可以减小learning rate
# * $$\eta^{t}=\frac{\eta}{\sqrt{t+1}}$$

# %% [markdown]
# * Adagrad

# %% [markdown]
# ![image.png](attachment:5466ab94-a36a-40ac-8ee6-50fe4728ddf8.png)
# ----------------------------------------------------------------
# ![image.png](attachment:4a0bf5ba-25c1-4b21-a438-6b754d938321.png)

# %% [markdown]
# ![image.png](attachment:53e09b16-fd3d-43b6-8e73-530b0386daf9.png)

# %% [markdown]
# ![image.png](attachment:d3d93970-5015-4e1b-9432-f8e66d6961a0.png)

# %% [markdown]
# ![image.png](attachment:454c03fb-1388-4aaa-ad2f-2d4a0c029cc0.png)

# %% [markdown]
# ![image.png](attachment:3a38ad61-9c54-443a-8dbb-1becf8424890.png)
