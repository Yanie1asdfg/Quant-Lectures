# %% [markdown]
# # **因子收益率分析**

# %% [markdown]
# ![image.png](attachment:f8df4599-6505-48db-92ed-06c3b2d0a28d.png)

# %% [markdown]
# > 因子收益率分析需要确定因子在不同股票位置上的表现，比如我们知道市值因子越小越好，但从何得来

# %% [markdown]
# ![image.png](attachment:1d9c4f46-b9b5-47b8-b0a2-8a57fa918fde.png)

# %% [markdown]
# ![image.png](attachment:c12f255e-c657-4059-a7c5-6c0a78e3780d.png)

# %% [markdown]
# 因子收益率即因子的贡献比重

# %% [markdown]
# ![image.png](attachment:64529773-b65b-4522-ab4a-fa1236cccabf.png)

# %% [markdown]
# ![image.png](attachment:8adb1bb6-68d6-45ed-af98-ae16b6ef7462.png)

# %% [markdown]
# ![image.png](attachment:4c62d9bc-345c-4249-ad65-11dafab2225f.png)

# %% [markdown]
# ![image.png](attachment:393773b5-c6f3-41ac-8b15-4b072faa2018.png)
