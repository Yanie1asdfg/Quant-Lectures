# %% [markdown]
# # 列表（List）

# %% [markdown]
# 列表是个有序类型（Sequence Type）的容器，其中包含着有索引编号的元素。列表是可变序列

# %% [markdown]
# ### 增

# %% [markdown]
# * 把一个元素添加到列表的结尾：list.append(x)

# %%
list = ['000001','000002'] 
list.append('000003')
list
# Out:
# ['000001', '000002', '000003']

# %%
* 在列表末尾追加列表： list.extend(list)

# %%
list1 = ['000001', '000002', '000003']
list2 = ['000004', '000005', '000006']
list1.extend(list2)
list1
# Out:
# ['000001', '000002', '000003', '000004', '000005', '000006']

# %% [markdown]
# * 在指定位置插入一个元素: list.insert(i, x)  i 为插入的索引，x为插入的值

# %%
list1 = ['000001', '000002', '000003', '000004', '000005', '000006']
list1.insert(1, '600519')
list1
# Out:
# ['000001', '600519', '000002', '000003', '000004', '000005', '000006']

# %% [markdown]
# ### 删

# %% [markdown]
# * 删除列表中值为 x 的第一个元素：list.remove(x) 如果没有这样的元素，就会返回一个错误。

# %%
list = [4,3,7,9,5,3,6,8,0,4,3]
list.remove(4)
list  #如果有重复，则删除第一个
# Out:
# [3, 7, 9, 5, 3, 6, 8, 0, 4, 3]

# %% [markdown]
# * 从列表的指定位置移除元素   并且返回索引元素

# %%
list = [4,3,7,9,5,3,6,8,0,4,3]
list_pop=list.pop(4)
list_pop,list
# Out:
# (5, [4, 3, 7, 9, 3, 6, 8, 0, 4, 3])

# %% [markdown]
# * 移除列表中的所有项  list.clear()

# %%
list = [4,3,7,9,5,3,6,8,0,4,3]
list.clear()
list
# Out:
# []

# %% [markdown]
# * 切割一个列表

# %%
a = [-1, 1, 66.25, 333, 333, 1234.5]
del a[0]
a
# Out:
# [1, 66.25, 333, 333, 1234.5]

# %%
a = [-1, 1, 66.25, 333, 333, 1234.5]
del a[2:4]
a
# Out:
# [-1, 1, 333, 1234.5]

# %% [markdown]
# ### 查，索引

# %%
a = [-1, 1, 66.25, 333, 333, 1234.5]
a[:],a[2:5]
# Out:
# ([-1, 1, 66.25, 333, 333, 1234.5], [66.25, 333, 333])

# %% [markdown]
# 返回列表中第一个值为 x 的元素的索引。如果没有匹配的元素就会返回一个错误。list.index(x)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

a = [-1, 1, 66.25, 333, 333, 1234.5]
a.index(333)
# a.index(27)
# Out:
# 3

# %% [markdown]
# 返回元素 x 在列表中出现的次数。 list.count(x)

# %% [markdown]
# ### 排序

# %% [markdown]
# 对列表中的元素进行排序   list.sort()

# %%
list = [4,3,7,9,5,3,6,8,0,4,3]
list.sort()
list
# Out:
# [0, 3, 3, 3, 4, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ### 倒置

# %% [markdown]
# 倒排列表中的元素： list.reverse()

# %%
list1 = ['000001', '000002', '000003', '000004', '000005', '000006']
list1.reverse()
list1
# Out:
# ['000006', '000005', '000004', '000003', '000002', '000001']

# %% [markdown]
# ### 遍历

# %%
seasons = ['Spring', 'Summer', 'Fall', 'Winter']
for i in seasons:
    print(i)
# Out:
# Spring
# Summer
# Fall
# Winter

# %%
for i, e in enumerate(seasons):
   print(i, e)
# Out:
# 0 Spring
# 1 Summer
# 2 Fall
# 3 Winter

# %% [markdown]
# 同时遍历两个或更多的序列，可以使用 zip() 组合：

# %%
questions = ['name', 'quest', 'favorite color']
answers = ['lancelot', 'the holy grail', 'blue']
for q, a in zip(questions, answers):
    print('What is your {0}?  It is {1}.'.format(q, a))
# Out:
# What is your name?  It is lancelot.
# What is your quest?  It is the holy grail.
# What is your favorite color?  It is blue.

# %% [markdown]
# 反向遍历一个列表

# %%
seasons = ['Spring', 'Summer', 'Fall', 'Winter']
for i in reversed(seasons):
    print(i)
# Out:
# Winter
# Fall
# Summer
# Spring

# %% [markdown]
# ### 列表推导式

# %%
a_range = range(10)
a_list = [x * x  for  x  in  a_range]
a_list
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# ### 其他操作

# %%
让列表中所有的树都大于0

# %%
list1= [-1, 1, 66.25, 333, 333, 1234.5]
[i for i in list1 if i>0]
# Out:
# [1, 66.25, 333, 333, 1234.5]

# %%
import numpy
list= [-1, -3, 66.25, 333, 333, 1234.5]
(numpy.array(list)>0).all()
# Out:
# False

# %%
import numpy
list= [-1, 1, 66.25, 333, 333, 1234.5]
(numpy.array(list)>0).any()
# Out:
# True

# %%
import numpy as np
list1= [-1,354,-23,45,32,-53, 1, 66.25, 333, 333, 1234.5]
o = [list1.index(x) for x in array if x<0]
o
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-f92702efb946> in <module>
#       2 list1= [-1,354,-23,45,32,-53, 1, 66.25, 333, 333, 1234.5]
#       3 array = np.array(list1)
# ----> 4 o = [array.index(x) for x in array if x<0]
#       5 o
#
# <ipython-input-12-f92702efb946> in <listcomp>(.0)
#       2 list1= [-1,354,-23,45,32,-53, 1, 66.25, 333, 333, 1234.5]
#       3 array = np.array(list1)
# ----> 4 o = [array.index(x) for x in array if x<0]
#       5 o
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %% [markdown]
# # 元组（Tuple）

# %% [markdown]
# 与列表相似的一个容器，元组，用()表示

# %% [markdown]
# 他们之间的区别
# * List 是可变有序容器，Tuple 是不可变有序容器。    可变/不可变  有序/无序  可重复/不可重复
# * List 用方括号标识 []，Tuple 用圆括号 标识 ()。

# %% [markdown]
# 创建一个元组的时候，用圆括号：
# a = ()

# %% [markdown]
# 元组是不可变序列，所以，你没办法直接从里面删除，替换元素。
# 但是，你可以在末尾追加元素。即：当前已有部分不可变

# %%
a = (1,2,3)
b = a+(3,4,5,6)
b
# Out:
# (1, 2, 3, 3, 4, 5, 6)

# %%
b[1]
b[2:5]
# Out:
# 2
# (3, 4, 5)

# %% [markdown]
# 列表和元组的应用：
# > 在将来需要更改的时候，创建 List
# > 在将来不需要更改的时候，创建 Tuple
# > Tuple 相对于 List 占用更小的内存

# %% [markdown]
# ### 遍历

# %%
seasons = ('Spring', 'Summer', 'Fall', 'Winter')
for i in seasons:
    print(i)
# Out:
# Spring
# Summer
# Fall
# Winter

# %%
for i, e in enumerate(seasons):
   print(i, e)
# Out:
# 0 Spring
# 1 Summer
# 2 Fall
# 3 Winter

# %% [markdown]
# # 集合（Set）

# %% [markdown]
# > 字符串是不可变，有序的容器 ' '," "
# > 列表是可变，有序的容器 []
# > 元组是不可变，有序的容器 ()

# %% [markdown]
# 集合又分为两种，Set，可变的，Frozen Set，不可变的。而且它是无序的，不包含重合元素的

# %% [markdown]
# 这里只讲可变集合

# %% [markdown]
# 创建一个集合

# %%
a = {2, 3, 5, 7, 11, 13, 17}
a
# Out:
# {2, 3, 5, 7, 11, 13, 17}

# %% [markdown]
# 创建空集合的时候，必须用 set()，而不能用 {}:

# %%
b = set()
b
# Out:
# set()

# %% [markdown]
# ### 去重

# %%
a = [2,3,3,5,5,2,8,7,7]
set(a)
b = (2,3,3,5,5,2,8,7,7)
set(b)
# Out:
# {2, 3, 5, 7, 8}
# {2, 3, 5, 7, 8}

# %% [markdown]
# 集合不是有序容器，不可查

# %% [markdown]
# ### 增

# %%
a = {1,2,3}
a.add('sh')
a
# Out:
# {1, 2, 3, 'sh'}

# %% [markdown]
# ### 删

# %%
a = {1, 2, 3, 'sh'}
a.remove('sh')
a
# Out:
# {1, 2, 3}

# %%
a = {1, 2, 3, 'sh'}
a.discard(4)
a
# Out:
# {1, 2, 3, 'sh'}

# %% [markdown]
# ### 操作

# %%
a = {'000001', '000002', '000003', '000004'}
b = {'000003', '000004', '000005', '000006'}

# %%
a-b  #取在a中但不在b中的元素
# Out:
# {'000001', '000002'}

# %%
b-a #取在b中但不在a中的元素
# Out:
# {'000005', '000006'}

# %%
a | b #取a,b中所有的元素
# Out:
# {'000001', '000002', '000003', '000004', '000005', '000006'}

# %%
a & b #取a,b中重合的元素
# Out:
# {'000003', '000004'}

# %%
a^b #取a,b中不重合的元素
# Out:
# {'000001', '000002', '000005', '000006'}

# %%
for i in a:
    print(i)
# Out:
# 000004
# 000001
# 000002
# 000003

# %% [markdown]
# # 字典（Dictionary）

# %% [markdown]
# 字典是一种含有键，值得映射容器

# %% [markdown]
# > 字符串是不可变，有序的容器 '',""
# > 列表是可变，有序的容器 []
# > 元组是不可变，有序的容器 ()
# > 集合：可变/不可变，无序，不可重复{}

# %% [markdown]
# 字典是可变，不可重复容器，无序的键=>值对集合

# %% [markdown]
# 字典里的每个元素，由两部分组成，key（键）和 value（值），二者由一个冒号连接，用 key 作为索引，并映射到与它匹配的 value：

# %% [markdown]
# 字典是唯一的，如果有重复，会自动去重,保留后面的一个

# %%
sq = {'one':6575, 'two':8982, 'three':2598, 'four':1225, 'four':6585}
sq
# Out:
# {'one': 6575, 'two': 8982, 'three': 2598, 'four': 6585}

# %% [markdown]
# ### 增

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

a = {'a':1, 'b':2, 'c':3}
a['d']=4 #增
a
a['a']=5 #更新
a
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# {'a': 5, 'b': 2, 'c': 3, 'd': 4}

# %%
a = {'a':1, 'b':2, 'c':3}
b = {'d':4,'e':5,'f':6}
a.update(b)
a
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %% [markdown]
# ### 删

# %%
a = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}
del a['a']
a
# Out:
# {'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
a = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}
b = a.pop('a',1)
b,a
# Out:
# (1, {'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6})

# %% [markdown]
# ### 查 判断存在

# %%
#通过键获取值
a = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}
a['a']
# Out:
# 1

# %%
a = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}
'a' in a
# Out:
# True

# %%
a = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}
a.keys(),a.values()
# Out:
# (dict_keys(['a', 'b', 'c', 'd', 'e', 'f']), dict_values([1, 2, 3, 4, 5, 6]))

# %%
# 将键值转换为列表
a = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}
list(a.keys()),list(a.values())
# Out:
# (['a', 'b', 'c', 'd', 'e', 'f'], [1, 2, 3, 4, 5, 6])

# %%
#两列表转换为字典
a = ['a', 'b', 'c', 'd', 'e', 'f']
b = [1, 2, 3, 4, 5, 6]
dict(zip(a,b))
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
'a' in a.keys(),1 in a.values()
# Out:
# (True, True)

# %%
('a',1) in a.items()
# Out:
# True

# %% [markdown]
# ### 遍历

# %%
a = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}
for i in a:
    print(i,a[i])
# Out:
# a 1
# b 2
# c 3
# d 4
# e 5
# f 6

# %%
for key,value in a.items():
    print(key,value)
# Out:
# a 1
# b 2
# c 3
# d 4
# e 5
# f 6

# %% [markdown]
# 字符串，列表，元组，集合，字典 可变/不可变 有序/无序 可重复/不可重复 总结

# %% [markdown]
# ![image.png](attachment:image.png)
