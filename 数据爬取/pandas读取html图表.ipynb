# %%
from bs4 import BeautifulSoup
import urllib.parse
import pandas as pd

# %%
url = 'http://vip.stock.finance.sina.com.cn/q/view/vFutures_Positions_cjcc.php?t_breed=J2109&t_date=2021-01-27'
head = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36 Edg/89.0.774.63"}
data = pd.read_html(url)
data[3]   # 3为多单持仓   4为空单持仓
# Out:
#    名次  会员简称  多单持仓  比上交易增减
# 0  合计   NaN   NaN     NaN

# %%
df = data[3]
df.set_index('会员简称',inplace = True)

# %%
df = df['多单持仓']
df,type(df)
# Out:
# (会员简称
#  银河期货     3789
#  东海期货     2418
#  东证期货     2397
#  国泰君安     2168
#  一德期货     1376
#  国信期货     1328
#  永安期货     1272
#  华泰期货     1221
#  广发期货     1172
#  中信建投     1170
#  中信期货     1169
#  中财期货     1073
#  海通期货      958
#  方正中期      867
#  国富期货      864
#  申银万国      770
#  海证期货      745
#  西南期货      696
#  国投安信      662
#  格林大华      650
#  NaN     26765
#  Name: 多单持仓, dtype: int64,
#  pandas.core.series.Series)

# %%
url = 'http://vip.stock.finance.sina.com.cn/q/view/vFutures_Positions_cjcc.php?t_breed=J2109&t_date=2021-03-29'
head = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36 Edg/89.0.774.63"}
data = pd.read_html(url)
   # 3为多单持仓   4为空单持仓

# %%
df1 = data[3]
df1.set_index('会员简称',inplace = True)

# %%
df1 = df1['多单持仓']
df1,type(df1)
# Out:
# (会员简称
#  东海期货     4824
#  银河期货     4480
#  东证期货     3340
#  国泰君安     1478
#  一德期货     1239
#  广发期货     1120
#  国信期货     1091
#  华泰期货     1079
#  中财期货     1075
#  申银万国     1072
#  中信建投     1013
#  中信期货      989
#  永安期货      926
#  中辉期货      855
#  方正中期      849
#  西南期货      702
#  国投安信      656
#  华闻期货      641
#  平安期货      641
#  徽商期货      572
#  NaN     28642
#  Name: 多单持仓, dtype: int64,
#  pandas.core.series.Series)

# %%
df2 = pd.concat([df, df1], axis=1)
df2
# Out:
#          多单持仓     多单持仓
# 会员简称
# 银河期货   3789.0   4480.0
# 东海期货   2418.0   4824.0
# 东证期货   2397.0   3340.0
# 国泰君安   2168.0   1478.0
# 一德期货   1376.0   1239.0
# 国信期货   1328.0   1091.0
# 永安期货   1272.0    926.0
# 华泰期货   1221.0   1079.0
# 广发期货   1172.0   1120.0
# 中信建投   1170.0   1013.0
# 中信期货   1169.0    989.0
# 中财期货   1073.0   1075.0
# 海通期货    958.0      NaN
# 方正中期    867.0    849.0
# 国富期货    864.0      NaN
# 申银万国    770.0   1072.0
# 海证期货    745.0      NaN
# 西南期货    696.0    702.0
# 国投安信    662.0    656.0
# 格林大华    650.0      NaN
# NaN   26765.0  28642.0
# 中辉期货      NaN    855.0
# 华闻期货      NaN    641.0
# 平安期货      NaN    641.0
# 徽商期货      NaN    572.0
