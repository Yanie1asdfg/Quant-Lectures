# %% [markdown]
# # **多因子策略-回测阶段**

# %% [markdown]
# ![image.png](attachment:92d8188e-77fe-4309-8eee-638fa989c5e9.png)

# %% [markdown]
# 1.回测内容的确定

# %% [markdown]
# * 回测区间
# * 因子选股
# * 调仓周期

# %% [markdown]
# > 调仓周期对于多因子策略并不是特别重要，一般是按一个月或者一个季度进行调仓,持有一个周期，下个周期再进行调仓

# %% [markdown]
# 在多因子策略当中，选股通过因子选择，怎么结合筛选出来的多个因子选择股票？

# %% [markdown]
# 2.回测选股方法

# %% [markdown]
# ![image.png](attachment:14647b39-2bd6-42b1-9b88-4505f1f8696f.png)

# %% [markdown]
# 3.回测区间与调仓周期

# %% [markdown]
# ![image.png](attachment:e98d55f8-f553-4eb5-bb63-2a57deb7329e.png)

# %% [markdown]
# ![image.png](attachment:d518ba12-8a2e-4a7f-a043-1393ef802408.png)
