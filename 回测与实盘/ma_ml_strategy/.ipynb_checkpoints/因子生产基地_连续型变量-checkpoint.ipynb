# %%
# 准备数据
import os
path = r'E:\repo\ml_bt\MA'
all_path = [os.path.join(path,x) for x in os.listdir(path) if 'MA' in x]
all_path[-1]
# Out:
# 'E:\\repo\\ml_bt\\MA\\MA2205.csv'

# %%
import pandas as pd
data = pd.read_csv(all_path[-1],index_col=0)
data
# Out:
#                       date    open    high     low   close   volume  \
# 0      2021-05-19 21:05:00  2721.0  2721.0  2598.0  2606.0      2.0
# 1      2021-05-19 21:10:00  2606.0  2648.0  2606.0  2648.0      1.0
# 2      2021-05-19 21:15:00  2648.0  2648.0  2648.0  2648.0      0.0
# 3      2021-05-19 21:20:00  2648.0  2648.0  2648.0  2648.0      0.0
# 4      2021-05-19 21:25:00  2648.0  2648.0  2637.0  2637.0      1.0
# ...                    ...     ...     ...     ...     ...      ...
# 9997   2021-12-21 14:40:00  2575.0  2579.0  2571.0  2575.0  11741.0
# 9998   2021-12-21 14:45:00  2575.0  2579.0  2572.0  2576.0   9408.0
# 9999   2021-12-21 14:50:00  2575.0  2577.0  2568.0  2570.0  13602.0
# 10000  2021-12-21 14:55:00  2570.0  2570.0  2556.0  2562.0  48947.0
# 10001  2021-12-21 15:00:00  2563.0  2569.0  2560.0  2568.0  30384.0
#
#               money  open_interest
# 0      5.204000e+04            2.0
# 1      2.647000e+04            2.0
# 2      0.000000e+00            2.0
# 3      0.000000e+00            2.0
# 4      2.637000e+04            3.0
# ...             ...            ...
# 9997   3.042093e+08       875298.0
# 9998   2.437613e+08       878924.0
# 9999   3.395225e+08       884105.0
# 10000  1.254333e+09       896922.0
# 10001  7.866418e+08       902182.0
#
# [10002 rows x 8 columns]

# %%
# 历史数据走势
data['close'].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
# 导入因子
from CreateFeatures import * 
data = feature9(data,10)
data
# Out:
#                       date    open    high     low   close   volume  \
# 0      2021-05-19 21:05:00  2721.0  2721.0  2598.0  2606.0      2.0
# 1      2021-05-19 21:10:00  2606.0  2648.0  2606.0  2648.0      1.0
# 2      2021-05-19 21:15:00  2648.0  2648.0  2648.0  2648.0      0.0
# 3      2021-05-19 21:20:00  2648.0  2648.0  2648.0  2648.0      0.0
# 4      2021-05-19 21:25:00  2648.0  2648.0  2637.0  2637.0      1.0
# ...                    ...     ...     ...     ...     ...      ...
# 9997   2021-12-21 14:40:00  2575.0  2579.0  2571.0  2575.0  11741.0
# 9998   2021-12-21 14:45:00  2575.0  2579.0  2572.0  2576.0   9408.0
# 9999   2021-12-21 14:50:00  2575.0  2577.0  2568.0  2570.0  13602.0
# 10000  2021-12-21 14:55:00  2570.0  2570.0  2556.0  2562.0  48947.0
# 10001  2021-12-21 15:00:00  2563.0  2569.0  2560.0  2568.0  30384.0
#
#               money  open_interest  c_ma_ratio_10
# 0      5.204000e+04            2.0            NaN
# 1      2.647000e+04            2.0            NaN
# 2      0.000000e+00            2.0            NaN
# 3      0.000000e+00            2.0            NaN
# 4      2.637000e+04            3.0            NaN
# ...             ...            ...            ...
# 9997   3.042093e+08       875298.0       0.001435
# 9998   2.437613e+08       878924.0       0.001241
# 9999   3.395225e+08       884105.0       0.003219
# 10000  1.254333e+09       896922.0       0.005589
# 10001  7.866418e+08       902182.0       0.002873
#
# [10002 rows x 9 columns]

# %%
series = data.iloc[:,-1]

# %%
# 检查因子是否有空值
series.isnull().mean()
# Out:
# 0.0008998200359928015

# %%
# 因子的数据分布
series.plot(kind='kde',color='r')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# 对于分类型标签
import matplotlib.pyplot as plt
fig, ax1 = plt.subplots(figsize=(12,8))
color = 'tab:red'
ax1.set_xlabel('index')
ax1.set_ylabel('price', color=color)
ax1.plot(data.index, data.close, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # 创建共用x轴的第二个y轴

color = 'tab:blue'
ax2.set_ylabel('label', color=color)
ax2.plot(data.index, series, color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()
plt.show()
