# %% [markdown]
# # **多因子合成**

# %% [markdown]
# 应用PCA进行多个高相关因子的合成

# %% [markdown]
# ![image.png](attachment:f0300c54-77ed-4097-8fad-c940af2c0aaf.png)

# %% [markdown]
# 每个量化公司都有自己的一个因子库，主要的区别在于因子的合成不一样，所以每个公司据此的操作也不一样

# %% [markdown]
# ![image.png](attachment:73995d29-a968-4c63-b9af-8bc0481b5ec9.png)

# %% [markdown]
# 回测阶段，调仓时，对于选出来的因子，哪些因子需要合成的结果去进行选股

# %% [markdown]
# 对因子的暴露度进行合成

# %% [markdown]
# ![image.png](attachment:2610cb2a-acdd-4dd8-8946-c3c5d85d8174.png)

# %% [markdown]
# ![image.png](attachment:574f9483-e48a-4179-a448-2e602ce7d3cc.png)
